# %%
from pathlib import Path

profiles_dir = Path.home() / ".dbt"
profiles_dir.mkdir(parents=True, exist_ok=True)

(profiles_dir / "profiles.yml").write_text("""\
hotel_analytics:
  target: dev
  outputs:
    dev:
      type: snowflake
      account: "BAJLLOB-CN38560"
      user: "alekyakastury"
      password: "JimmyPage@1234"
      role: "ACCOUNTADMIN"
      warehouse: "COMPUTE_WH"
      database: "HOTEL_ANALYTICS"
      schema: "STAGING"
      threads: 4
""")

print("profiles.yml created")
# Out:
# profiles.yml created

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aleky\anaconda\python.exe

# %%
# %pip install -U dbt-snowflake
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dbt-snowflake
#   Using cached dbt_snowflake-1.11.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting agate (from dbt-snowflake)
#   Downloading agate-1.14.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting certifi<2025.4.26 (from dbt-snowflake)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting dbt-adapters<2.0,>=1.22.4 (from dbt-snowflake)
#   Downloading dbt_adapters-1.22.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting dbt-common<2.0,>=1.10 (from dbt-snowflake)
#   Using cached dbt_common-1.37.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting dbt-core>=1.10.0rc0 (from dbt-snowflake)
#   Using cached dbt_core-1.11.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: snowflake-connector-python<5.0.0,>=4.0.0 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (4.1.1)
# Collecting dbt-protos<2.0,>=1.0.291 (from dbt-adapters<2.0,>=1.22.4->dbt-snowflake)
#   Downloading dbt_protos-1.0.419-py3-none-any.whl.metadata (859 bytes)
# Collecting mashumaro<3.15,>=3.9 (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.22.4->dbt-snowflake)
#   Using cached mashumaro-3.14-py3-none-any.whl.metadata (114 kB)
# Requirement already satisfied: protobuf<7.0,>=6.0 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from dbt-adapters<2.0,>=1.22.4->dbt-snowflake) (6.33.2)
# Requirement already satisfied: pytz>=2015.7 in c:\users\aleky\anaconda\lib\site-packages (from dbt-adapters<2.0,>=1.22.4->dbt-snowflake) (2024.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-adapters<2.0,>=1.22.4->dbt-snowflake) (4.12.2)
# Requirement already satisfied: Babel>=2.0 in c:\users\aleky\anaconda\lib\site-packages (from agate->dbt-snowflake) (2.16.0)
# Collecting isodate>=0.5.4 (from agate->dbt-snowflake)
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting leather>=0.3.2 (from agate->dbt-snowflake)
#   Using cached leather-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting parsedatetime!=2.5,>=2.1 (from agate->dbt-snowflake)
#   Using cached parsedatetime-2.6-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-slugify>=1.2.1 in c:\users\aleky\anaconda\lib\site-packages (from agate->dbt-snowflake) (5.0.2)
# Collecting pytimeparse>=1.1.5 (from agate->dbt-snowflake)
#   Using cached pytimeparse-1.1.8-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: tzdata>=2023.3 in c:\users\aleky\anaconda\lib\site-packages (from agate->dbt-snowflake) (2025.2)
# Collecting agate (from dbt-snowflake)
#   Using cached agate-1.9.1-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in c:\users\aleky\anaconda\lib\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (0.4.6)
# Collecting deepdiff<9.0,>=7.0 (from dbt-common<2.0,>=1.10->dbt-snowflake)
#   Using cached deepdiff-8.6.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: jinja2<4,>=3.1.3 in c:\users\aleky\anaconda\lib\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (3.1.6)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (4.23.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in c:\users\aleky\anaconda\lib\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (0.10.3)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from dbt-common<2.0,>=1.10->dbt-snowflake) (2.32.4)
# Collecting orderly-set<6,>=5.4.1 (from deepdiff<9.0,>=7.0->dbt-common<2.0,>=1.10->dbt-snowflake)
#   Using cached orderly_set-5.5.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aleky\anaconda\lib\site-packages (from jinja2<4,>=3.1.3->dbt-common<2.0,>=1.10->dbt-snowflake) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\aleky\anaconda\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.10->dbt-snowflake) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\aleky\anaconda\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.10->dbt-snowflake) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\aleky\anaconda\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.10->dbt-snowflake) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\aleky\anaconda\lib\site-packages (from jsonschema<5.0,>=4.0->dbt-common<2.0,>=1.10->dbt-snowflake) (0.22.3)
# Requirement already satisfied: msgpack>=0.5.6 in c:\users\aleky\anaconda\lib\site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2.0,>=1.22.4->dbt-snowflake) (1.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\aleky\anaconda\lib\site-packages (from python-dateutil<3.0,>=2.0->dbt-common<2.0,>=1.10->dbt-snowflake) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aleky\anaconda\lib\site-packages (from requests<3.0.0->dbt-common<2.0,>=1.10->dbt-snowflake) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aleky\anaconda\lib\site-packages (from requests<3.0.0->dbt-common<2.0,>=1.10->dbt-snowflake) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aleky\anaconda\lib\site-packages (from requests<3.0.0->dbt-common<2.0,>=1.10->dbt-snowflake) (2.3.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (1.5.1)
# Requirement already satisfied: cryptography>=44.0.1 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (44.0.1)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=24.0.0 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (25.0.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (2.10.1)
# Requirement already satisfied: packaging in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (24.2)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (3.17.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (4.3.7)
# Requirement already satisfied: tomlkit in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (0.13.2)
# Requirement already satisfied: boto3>=1.24 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (1.42.23)
# Requirement already satisfied: botocore>=1.24 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (1.42.23)
# Requirement already satisfied: cffi>=1.12 in c:\users\aleky\anaconda\lib\site-packages (from cryptography>=44.0.1->snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (1.17.1)
# Requirement already satisfied: keyring<26.0.0,>=23.1.0 in c:\users\aleky\anaconda\lib\site-packages (from snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (25.6.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\aleky\anaconda\lib\site-packages (from keyring<26.0.0,>=23.1.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (0.2.2)
# Requirement already satisfied: jaraco.classes in c:\users\aleky\anaconda\lib\site-packages (from keyring<26.0.0,>=23.1.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (3.2.1)
# Requirement already satisfied: jaraco.functools in c:\users\aleky\anaconda\lib\site-packages (from keyring<26.0.0,>=23.1.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (4.1.0)
# Requirement already satisfied: jaraco.context in c:\users\aleky\anaconda\lib\site-packages (from keyring<26.0.0,>=23.1.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (0.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\aleky\anaconda\lib\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\alekya kastury\appdata\roaming\python\python313\site-packages (from boto3>=1.24->snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\aleky\anaconda\lib\site-packages (from cffi>=1.12->cryptography>=44.0.1->snowflake-connector-python<5.0.0,>=4.0.0->snowflake-connector-python[secure-local-storage]<5.0.0,>=4.0.0->dbt-snowflake) (2.21)
# Collecting click<9.0,>=8.2.0 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting daff>=1.3.46 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached daff-1.4.2-py3-none-any.whl.metadata (10 kB)
# Collecting dbt-extractor<=0.6,>=0.5.0 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached dbt_extractor-0.6.0-cp39-abi3-win_amd64.whl.metadata (4.6 kB)
# Collecting dbt-semantic-interfaces<0.10,>=0.9.0 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached dbt_semantic_interfaces-0.9.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: networkx<4.0,>=2.3 in c:\users\aleky\anaconda\lib\site-packages (from dbt-core>=1.10.0rc0->dbt-snowflake) (3.4.2)
# Requirement already satisfied: pydantic<3 in c:\users\aleky\anaconda\lib\site-packages (from dbt-core>=1.10.0rc0->dbt-snowflake) (2.10.3)
# Requirement already satisfied: pyyaml>=6.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-core>=1.10.0rc0->dbt-snowflake) (6.0.2)
# Collecting snowplow-tracker<2.0,>=1.0.2 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached snowplow_tracker-1.1.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting sqlparse<0.5.5,>=0.5.0 (from dbt-core>=1.10.0rc0->dbt-snowflake)
#   Using cached sqlparse-0.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: importlib-metadata<9,>=6.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.10.0rc0->dbt-snowflake) (8.5.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in c:\users\aleky\anaconda\lib\site-packages (from dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.10.0rc0->dbt-snowflake) (10.3.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\aleky\anaconda\lib\site-packages (from importlib-metadata<9,>=6.0->dbt-semantic-interfaces<0.10,>=0.9.0->dbt-core>=1.10.0rc0->dbt-snowflake) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aleky\anaconda\lib\site-packages (from pydantic<3->dbt-core>=1.10.0rc0->dbt-snowflake) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\aleky\anaconda\lib\site-packages (from pydantic<3->dbt-core>=1.10.0rc0->dbt-snowflake) (2.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\aleky\anaconda\lib\site-packages (from python-slugify>=1.2.1->agate->dbt-snowflake) (1.3)
# Using cached dbt_snowflake-1.11.1-py3-none-any.whl (75 kB)
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading dbt_adapters-1.22.5-py3-none-any.whl (172 kB)
# Using cached dbt_common-1.37.2-py3-none-any.whl (87 kB)
# Using cached agate-1.9.1-py2.py3-none-any.whl (95 kB)
# Downloading dbt_protos-1.0.419-py3-none-any.whl (167 kB)
# Using cached deepdiff-8.6.1-py3-none-any.whl (91 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached mashumaro-3.14-py3-none-any.whl (92 kB)
# Using cached orderly_set-5.5.0-py3-none-any.whl (13 kB)
# Using cached dbt_core-1.11.2-py3-none-any.whl (1.0 MB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached dbt_extractor-0.6.0-cp39-abi3-win_amd64.whl (277 kB)
# Using cached dbt_semantic_interfaces-0.9.0-py3-none-any.whl (147 kB)
# Using cached snowplow_tracker-1.1.0-py3-none-any.whl (44 kB)
# Using cached sqlparse-0.5.4-py3-none-any.whl (45 kB)
# Using cached daff-1.4.2-py3-none-any.whl (144 kB)
# Using cached leather-0.4.1-py3-none-any.whl (30 kB)
# Using cached parsedatetime-2.6-py3-none-any.whl (42 kB)
# Using cached pytimeparse-1.1.8-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: pytimeparse, parsedatetime, leather, daff, sqlparse, orderly-set, mashumaro, isodate, dbt-protos, dbt-extractor, click, certifi, deepdiff, agate, snowplow-tracker, dbt-semantic-interfaces, dbt-common, dbt-adapters, dbt-core, dbt-snowflake
#
#    -- -------------------------------------  1/20 [parsedatetime]
#    -- -------------------------------------  1/20 [parsedatetime]
#    -- -------------------------------------  1/20 [parsedatetime]
#    -- -------------------------------------  1/20 [parsedatetime]
#    ---- -----------------------------------  2/20 [leather]
#    ---- -----------------------------------  2/20 [leather]
#    ---- -----------------------------------  2/20 [leather]
#    ---- -----------------------------------  2/20 [leather]
#    ---- -----------------------------------  2/20 [leather]
#    ------ ---------------------------------  3/20 [daff]
#    ------ ---------------------------------  3/20 [daff]
#    -------- -------------------------------  4/20 [sqlparse]
#    -------- -------------------------------  4/20 [sqlparse]
#    -------- -------------------------------  4/20 [sqlparse]
#    -------- -------------------------------  4/20 [sqlparse]
#    ---------- -----------------------------  5/20 [orderly-set]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    ------------ ---------------------------  6/20 [mashumaro]
#    -------------- -------------------------  7/20 [isodate]
#    -------------- -------------------------  7/20 [isodate]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ---------------- -----------------------  8/20 [dbt-protos]
#    ------------------ ---------------------  9/20 [dbt-extractor]
#    -------------------- ------------------- 10/20 [click]
#    -------------------- ------------------- 10/20 [click]
#    -------------------- ------------------- 10/20 [click]
#    ---------------------- ----------------- 11/20 [certifi]
#    ------------------------ --------------- 12/20 [deepdiff]
#    ------------------------ --------------- 12/20 [deepdiff]
#    ------------------------ --------------- 12/20 [deepdiff]
#    ------------------------ --------------- 12/20 [deepdiff]
#    ------------------------ --------------- 12/20 [deepdiff]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    -------------------------- ------------- 13/20 [agate]
#    ---------------------------- ----------- 14/20 [snowplow-tracker]
#    ---------------------------- ----------- 14/20 [snowplow-tracker]
#    ---------------------------- ----------- 14/20 [snowplow-tracker]
#    ---------------------------- ----------- 14/20 [snowplow-tracker]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    ------------------------------ --------- 15/20 [dbt-semantic-interfaces]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    -------------------------------- ------- 16/20 [dbt-common]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ---------------------------------- ----- 17/20 [dbt-adapters]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    ------------------------------------ --- 18/20 [dbt-core]
#    -------------------------------------- - 19/20 [dbt-snowflake]
#    -------------------------------------- - 19/20 [dbt-snowflake]
#    -------------------------------------- - 19/20 [dbt-snowflake]
#    -------------------------------------- - 19/20 [dbt-snowflake]
#    ---------------------------------------- 20/20 [dbt-snowflake]
#
# Successfully installed agate-1.9.1 certifi-2025.1.31 click-8.3.1 daff-1.4.2 dbt-adapters-1.22.5 dbt-common-1.37.2 dbt-core-1.11.2 dbt-extractor-0.6.0 dbt-protos-1.0.419 dbt-semantic-interfaces-0.9.0 dbt-snowflake-1.11.1 deepdiff-8.6.1 isodate-0.7.2 leather-0.4.1 mashumaro-3.14 orderly-set-5.5.0 parsedatetime-2.6 pytimeparse-1.1.8 snowplow-tracker-1.1.0 sqlparse-0.5.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script daff.exe is installed in 'C:\Users\Alekya Kastury\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script sqlformat.exe is installed in 'C:\Users\Alekya Kastury\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script deep.exe is installed in 'C:\Users\Alekya Kastury\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dbt.exe is installed in 'C:\Users\Alekya Kastury\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !dbt --version
# Out:
# Core:
#   - installed: 1.10.15
#   - latest:    1.11.2  - Update available!
#
#   Your version of dbt-core is out of date!
#   You can find instructions for upgrading here:
#   https://docs.getdbt.com/docs/installation
#
# Plugins:
#   - postgres: 1.9.1 - Update available!
#
#   At least one plugin is out of date with dbt-core.
#   You can find instructions for upgrading here:
#   https://docs.getdbt.com/docs/installation

# %%
# Out:
# 01:18:02  Running with dbt=1.10.15
# 01:18:02  dbt version: 1.10.15
# 01:18:02  python version: 3.11.9
# 01:18:02  python path: C:\Users\Alekya Kastury\AppData\Local\Programs\Python\Python311\python.exe
# 01:18:02  os info: Windows-10-10.0.26200-SP0
# 01:18:02  Error importing adapter: No module named 'dbt.adapters.snowflake'
# 01:18:02  Using profiles dir at C:\Users\Alekya Kastury\.dbt
# 01:18:02  Using profiles.yml file at C:\Users\Alekya Kastury\.dbt\profiles.yml
# 01:18:02  Using dbt_project.yml file at C:\Users\Alekya Kastury\github\hotel-analytics-platform\dbt\hotel_analytics\dbt_project.yml
# 01:18:02  Configuration:
# 01:18:02    profiles.yml file [ERROR invalid]
# 01:18:02    dbt_project.yml file [OK found and valid]
# 01:18:02  Required dependencies:
# 01:18:02   - git [OK found]
#
# 01:18:02  Connection test skipped since no profile was found
# 01:18:02  1 check failed:
# 01:18:02  Profile loading failed for the following reason:
# Runtime Error
#   Credentials in profile "hotel_analytics", target "dev" invalid: Runtime Error
#     Could not find adapter type snowflake!
